# %% [markdown]
# # Checking Numpy Version

# %%
import numpy as np
print(f"NumPy version: {np.__version__}")
# Should show 1.24.x or similar
# Out:
# NumPy version: 2.3.5

# %%
import pandas as pd
print(f"pandas version: {np.__version__}")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.5 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\kiran\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\kiran\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
# ...

# %% [markdown]
# # Installing the upgraded version of Numpy and Pandas

# %%
# In Jupyter notebook cell
# !pip install --upgrade numpy pandas
# Out:
# ...
# WARNING: Skipping C:\Users\kiran\anaconda3\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\kiran\anaconda3\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\kiran\anaconda3\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\kiran\anaconda3\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'

# %%
import pandas as pd
print(f"pandas version: {np.__version__}")
# Out:
# pandas version: 2.3.5

# %% [markdown]
# # Creating data

# %%
# Restart kernel after downgrading

# Then restart your Jupyter kernel
import pandas as pd
import requests

# Sample Indian cities data structure
indian_cities_data = {
    'city': ['Mumbai', 'Delhi', 'Bangalore', 'Hyderabad', 'Chennai', 'Kolkata', 'Pune', 'Ahmedabad', 'Surat', 'Jaipur'],
    'state': ['Maharashtra', 'Delhi', 'Karnataka', 'Telangana', 'Tamil Nadu', 'West Bengal', 'Maharashtra', 'Gujarat', 'Gujarat', 'Rajasthan'],
    'latitude': [19.0760, 28.7041, 12.9716, 17.3850, 13.0827, 22.5726, 18.5204, 23.0225, 21.1702, 26.9124],
    'longitude': [72.8777, 77.1025, 77.5946, 78.4867, 80.2707, 88.3639, 73.8567, 72.5714, 72.8311, 75.7873],
    'population': [12442373, 11034555, 8443675, 6993262, 4681087, 4486679, 3124458, 5577940, 4467797, 3073350],
    'area_km2': [603, 1484, 709, 650, 426, 205, 331, 464, 327, 485]
}

df_india = pd.DataFrame(indian_cities_data)
print("Indian Cities Data:")
print(df_india)
# Out:
# Indian Cities Data:
#         city        state  latitude  longitude  population  area_km2
# 0     Mumbai  Maharashtra   19.0760    72.8777    12442373       603
# 1      Delhi        Delhi   28.7041    77.1025    11034555      1484
# 2  Bangalore    Karnataka   12.9716    77.5946     8443675       709
# 3  Hyderabad    Telangana   17.3850    78.4867     6993262       650
# 4    Chennai   Tamil Nadu   13.0827    80.2707     4681087       426
# 5    Kolkata  West Bengal   22.5726    88.3639     4486679       205
# 6       Pune  Maharashtra   18.5204    73.8567     3124458       331
# 7  Ahmedabad      Gujarat   23.0225    72.5714     5577940       464
# 8      Surat      Gujarat   21.1702    72.8311     4467797       327
# 9     Jaipur    Rajasthan   26.9124    75.7873     3073350       485

# %% [markdown]
# # Transferring a Data frame into a CSV File

# %%
# If you already have a DataFrame called 'df'
df_india.to_csv('my_india_data.csv', index=False)
print("CSV file saved successfully!")
# Out:
# CSV file saved successfully!

# %%
import pandas as pd
cities = pd.read_csv("my_india_data.csv")
print(cities.head())
# Out:
#         city        state  latitude  longitude  population  area_km2
# 0     Mumbai  Maharashtra   19.0760    72.8777    12442373       603
# 1      Delhi        Delhi   28.7041    77.1025    11034555      1484
# 2  Bangalore    Karnataka   12.9716    77.5946     8443675       709
# 3  Hyderabad    Telangana   17.3850    78.4867     6993262       650
# 4    Chennai   Tamil Nadu   13.0827    80.2707     4681087       426

# %% [markdown]
# # Extracting Data

# %%
# extracting the data we are interested in
latitude, longitude = cities["latitude"], cities["longitude"]
population, area = cities["population"], cities["area_km2"]

# %% [markdown]
# # Making Graph

# %%
# to scatter the points, using size and color but without label
import numpy as np
import matplotlib.pyplot as plt
import seaborn
seaborn.set()

plt.scatter(longitude, latitude, label=None, c=np.log10(population),
            cmap='viridis', s=area, linewidth=0, alpha=0.5)
plt.axis('equal')  # Fixed: removed 'aspect=' parameter
plt.xlabel('Longitude')
plt.ylabel('Latitude') 
plt.colorbar(label='log$_{10}$(population)')
plt.clim(3, 7)

# Create legend with empty lists for desired sizes
for area_size in [100, 300, 500]:  # Changed variable name to avoid conflict
    plt.scatter([], [], c='k', alpha=0.3, s=area_size, label=str(area_size) + ' km$^2$')

plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='City Areas')
plt.title("Area and Population of Indian Cities")
plt.show()
